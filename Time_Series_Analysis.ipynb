# %% [markdown]
# # **Project 2: Time series Analysis**
# Name: Rian Renold Dbritto
#
# NUID: 002026598

# %% [markdown]
# # **Stress and Affect Detection**

# %% [markdown]
# ## **Importing Files**

# %%
import pickle
import numpy as np
import pandas as pd

# %%
with open('/content/drive/MyDrive/WESAD FILES/S2/S2.pkl', 'rb') as f2:
    data1 = pickle.load(f2, encoding='latin1')

# %%
with open('/content/drive/MyDrive/WESAD FILES/S4/S4.pkl', 'rb') as f4:
    data2 = pickle.load(f4, encoding='latin1')

# %%
with open('/content/drive/MyDrive/WESAD FILES/S6/S6.pkl', 'rb') as f6:
    data3 = pickle.load(f6, encoding='latin1')

# %%
with open('/content/drive/MyDrive/WESAD FILES/S8/S8.pkl', 'rb') as f8:
    data4 = pickle.load(f8, encoding='latin1')

# %%
with open('/content/drive/MyDrive/WESAD FILES/S10/S10.pkl', 'rb') as f10:
    data5 = pickle.load(f10, encoding='latin1')

# %% [markdown]
# Checking of the data is uploaded

# %%
data1
# Out:
# {'signal': {'chest': {'ACC': array([[ 0.95539999, -0.222     , -0.55799997],
#           [ 0.92579997, -0.2216    , -0.55379999],
#           [ 0.90820003, -0.21960002, -0.53920001],
#           ...,
#           [ 0.87179995, -0.12379998, -0.30419999],
#           [ 0.87300003, -0.12339997, -0.30260003],
#           [ 0.87020004, -0.12199998, -0.30220002]]),
#    'ECG': array([[ 0.02142334],
#           [ 0.02032471],
#           [ 0.01652527],
#           ...,
#           [-0.00544739],
#           [ 0.00013733],
#           [ 0.0040741 ]]),
#    'EMG': array([[-0.00444031],
#           [ 0.00434875],
#           [ 0.00517273],
#           ...,
#           [-0.01716614],
#           [-0.02897644],
#           [-0.02357483]]),
#    'EDA': array([[5.25054932],
#           [5.26733398],
#           [5.24330139],
#           ...,
#           [0.36048889],
#           [0.36582947],
#           [0.365448  ]]),
#    'Temp': array([[30.120758],
#           [30.129517],
# ...

# %% [markdown]
# # **Extracting chest signals and labels for S2**

# %%
chest_data2 = data1['signal']['chest']
labels2 = data1['label']
ecg2 = chest_data2['ECG']

print("Length of ECG signal for S2:", len(ecg2))
print("Shape of labels for S2:", np.array(labels2).shape)
# Out:
# Length of ECG signal for S2: 4255300
# Shape of labels for S2: (4255300,)

# %%
chest_data2
# Out:
# {'ACC': array([[ 0.95539999, -0.222     , -0.55799997],
#         [ 0.92579997, -0.2216    , -0.55379999],
#         [ 0.90820003, -0.21960002, -0.53920001],
#         ...,
#         [ 0.87179995, -0.12379998, -0.30419999],
#         [ 0.87300003, -0.12339997, -0.30260003],
#         [ 0.87020004, -0.12199998, -0.30220002]]),
#  'ECG': array([[ 0.02142334],
#         [ 0.02032471],
#         [ 0.01652527],
#         ...,
#         [-0.00544739],
#         [ 0.00013733],
#         [ 0.0040741 ]]),
#  'EMG': array([[-0.00444031],
#         [ 0.00434875],
#         [ 0.00517273],
#         ...,
#         [-0.01716614],
#         [-0.02897644],
#         [-0.02357483]]),
#  'EDA': array([[5.25054932],
#         [5.26733398],
#         [5.24330139],
#         ...,
#         [0.36048889],
#         [0.36582947],
#         [0.365448  ]]),
#  'Temp': array([[30.120758],
#         [30.129517],
#         [30.138214],
#         ...,
#         [31.459229],
#         [31.484283],
# ...

# %%
labels2
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int32)

# %%
ecg2
# Out:
# array([[ 0.02142334],
#        [ 0.02032471],
#        [ 0.01652527],
#        ...,
#        [-0.00544739],
#        [ 0.00013733],
#        [ 0.0040741 ]])

# %%
chest_data3 = data2['signal']['chest']
labels3 = data2['label']
ecg3 = chest_data3['ECG']

print("Length of ECG signal for S4:", len(ecg3))
print("Shape of labels for S4:", np.array(labels3).shape)
# Out:
# Length of ECG signal for S4: 4496100
# Shape of labels for S4: (4496100,)

# %%
chest_data4 = data3['signal']['chest']
labels4 = data3['label']
ecg4 = chest_data4['ECG']

print("Length of ECG signal for S6:", len(ecg4))
print("Shape of labels for S6:", np.array(labels4).shape)
# Out:
# Length of ECG signal for S6: 4949700
# Shape of labels for S6: (4949700,)

# %%
chest_data5 = data4['signal']['chest']
labels5 = data4['label']
ecg5 = chest_data5['ECG']

print("Length of ECG signal for S8:", len(ecg5))
print("Shape of labels for S8:", np.array(labels5).shape)
# Out:
# Length of ECG signal for S8: 3826200
# Shape of labels for S8: (3826200,)

# %%
chest_data6 = data5['signal']['chest']
labels6 = data5['label']
ecg6 = chest_data6['ECG']

print("Length of ECG signal for S10:", len(ecg6))
print("Shape of labels for S10:", np.array(labels6).shape)
# Out:
# Length of ECG signal for S10: 3847200
# Shape of labels for S10: (3847200,)

# %% [markdown]
# # **Coverting the files into tabular form**

# %%
import pandas as pd

data11 = data1['signal']['chest']['ACC']
data12 = data2['signal']['chest']['ACC']
data13 = data3['signal']['chest']['ACC']
data14 = data4['signal']['chest']['ACC']
data15 = data5['signal']['chest']['ACC']
dfS1 = pd.DataFrame(data = data11, columns = ['acc_x', 'acc_y', 'acc_z'])
dfS2 = pd.DataFrame(data = data12, columns = ['acc_x', 'acc_y', 'acc_z'])
dfS3 = pd.DataFrame(data = data13, columns = ['acc_x', 'acc_y', 'acc_z'])
dfS4 = pd.DataFrame(data = data14, columns = ['acc_x', 'acc_y', 'acc_z'])
dfS5 = pd.DataFrame(data = data15, columns = ['acc_x', 'acc_y', 'acc_z'])

def add_multiple_columns(dfS1, column_names, data1, data1_column):
    for col in column_names:
        dfS1[col] = data1['signal']['chest'][col]
    return dfS1

column_names = ['ECG', 'EMG', 'EDA', 'Temp', 'Resp']
dfS1 = add_multiple_columns(dfS1, column_names, data1, 'ECG')
dfS2 = add_multiple_columns(dfS2, column_names, data2, 'ECG')
dfS3 = add_multiple_columns(dfS3, column_names, data3, 'ECG')
dfS4 = add_multiple_columns(dfS4, column_names, data4, 'ECG')
dfS5 = add_multiple_columns(dfS5, column_names, data5, 'ECG')

# %%
dfS1['label'] = data1['label']
dfS2['label'] = data2['label']
dfS3['label'] = data3['label']
dfS4['label'] = data4['label']
dfS5['label'] = data5['label']

# %%
dfS1['subject'] = data1['subject']
dfS2['subject'] = data2['subject']
dfS3['subject'] = data3['subject']
dfS4['subject'] = data4['subject']
dfS5['subject'] = data5['subject']

# %%
dfS2
# Out:
#           acc_x   acc_y   acc_z       ECG       EMG       EDA       Temp  \
# 0        1.5554 -0.0784  1.3624 -1.405380  0.044174  1.096344  32.506256
# 1        1.5130 -0.1070  1.4586 -1.399658  0.015472  1.094437  32.498779
# 2        1.4460 -0.1042  1.0604 -1.393387 -0.032043  1.094055  32.501770
# 3        1.3382 -0.0622  0.4234 -1.387436 -0.003799  1.094818  32.491302
# 4        1.1958 -0.0306 -0.0164 -1.381165  0.020370  1.092911  32.501770
# ...         ...     ...     ...       ...       ...       ...        ...
# 4496095  0.8926 -0.0810 -0.2290  0.082443  0.008743  2.483749  33.650391
# 4496096  0.8944 -0.0824 -0.2276  0.093796 -0.024673  2.480698  33.650391
# 4496097  0.8902 -0.0790 -0.2300  0.111282  0.005676  2.482605  33.630707
# 4496098  0.8908 -0.0798 -0.2266  0.125473  0.016251  2.494431  33.633728
# 4496099  0.8894 -0.0794 -0.2278  0.134995 -0.000137  2.494049  33.629181
#
#              Resp  label subject
# 0        2.836609      0      S4
# ...

# %% [markdown]
# # **Segmentation**

# %%
import pandas as pd
import numpy as np

def sample_state_data(df, state_value, num_samples=10, sample_length=4096):

    state_data = df[df['label'] == state_value]


    if len(state_data) < num_samples * sample_length:
        raise ValueError(f"Not enough data points for state {state_value}. "
                         f"Required: {num_samples * sample_length}, Available: {len(state_data)}")


    start_indices = np.random.choice(
        len(state_data) - sample_length + 1,
        size=num_samples,
        replace=False
    )
    start_indices.sort()


    sampled_segments = []
    for start in start_indices:
        end = start + sample_length
        sample = state_data.iloc[start:end]
        sampled_segments.append(sample)

    return sampled_segments

# %%
sampled_segments = sample_state_data(df=dfS2, state_value=1)

sampled_segments[0]
# Out:
#          acc_x   acc_y   acc_z       ECG       EMG       EDA       Temp  \
# 252353  0.7090 -0.4206 -0.5158 -0.053238 -0.007278  1.285553  32.713989
# 252354  0.7086 -0.4206 -0.5154 -0.054520 -0.002975  1.258850  32.752899
# 252355  0.7098 -0.4184 -0.5124 -0.056122  0.003525  1.293945  32.737946
# 252356  0.7090 -0.4200 -0.5138 -0.056946  0.008286  1.259613  32.708008
# 252357  0.7066 -0.4194 -0.5162 -0.055801  0.005081  1.330566  32.749908
# ...        ...     ...     ...       ...       ...       ...        ...
# 256444  0.7034 -0.4428 -0.5138  0.131424 -0.003708  1.284409  32.749908
# 256445  0.7022 -0.4442 -0.5102  0.137146 -0.003891  1.257706  32.739410
# 256446  0.7042 -0.4446 -0.5112  0.139252 -0.009384  1.250839  32.728943
# 256447  0.7022 -0.4414 -0.5140  0.141220 -0.016617  1.248550  32.740936
# 256448  0.7034 -0.4454 -0.5146  0.146896 -0.016068  1.275253  32.737946
#
#             Resp  label subject
# 252353 -1.492310      1      S4
# 252354 -1.495361      1      S4
# ...

# %%
sampled_segments_dfS1_1 = sample_state_data(df=dfS1, state_value=1, num_samples=10, sample_length=4096)
sampled_segments_dfS1_2 = sample_state_data(df=dfS1, state_value=2, num_samples=10, sample_length=4096)
sampled_segments_dfS1_3 = sample_state_data(df=dfS1, state_value=3, num_samples=10, sample_length=4096)
sampled_segments_dfS1_4 = sample_state_data(df=dfS1, state_value=4, num_samples=10, sample_length=4096)

sampled_segments_dfS2_1 = sample_state_data(df=dfS2, state_value=1, num_samples=10, sample_length=4096)
sampled_segments_dfS2_2 = sample_state_data(df=dfS2, state_value=2, num_samples=10, sample_length=4096)
sampled_segments_dfS2_3 = sample_state_data(df=dfS2, state_value=3, num_samples=10, sample_length=4096)
sampled_segments_dfS2_4 = sample_state_data(df=dfS2, state_value=4, num_samples=10, sample_length=4096)

sampled_segments_dfS3_1 = sample_state_data(df=dfS3, state_value=1, num_samples=10, sample_length=4096)
sampled_segments_dfS3_2 = sample_state_data(df=dfS3, state_value=1, num_samples=10, sample_length=4096)
sampled_segments_dfS3_3 = sample_state_data(df=dfS3, state_value=1, num_samples=10, sample_length=4096)
sampled_segments_dfS3_4 = sample_state_data(df=dfS3, state_value=1, num_samples=10, sample_length=4096)

sampled_segments_dfS4_1 = sample_state_data(df=dfS4, state_value=1, num_samples=10, sample_length=4096)
sampled_segments_dfS4_2 = sample_state_data(df=dfS4, state_value=1, num_samples=10, sample_length=4096)
sampled_segments_dfS4_3 = sample_state_data(df=dfS4, state_value=1, num_samples=10, sample_length=4096)
sampled_segments_dfS4_4 = sample_state_data(df=dfS4, state_value=1, num_samples=10, sample_length=4096)

sampled_segments_dfS5_1 = sample_state_data(df=dfS5, state_value=1, num_samples=10, sample_length=4096)
sampled_segments_dfS5_2 = sample_state_data(df=dfS5, state_value=1, num_samples=10, sample_length=4096)
sampled_segments_dfS5_3 = sample_state_data(df=dfS5, state_value=1, num_samples=10, sample_length=4096)
sampled_segments_dfS5_4 = sample_state_data(df=dfS5, state_value=1, num_samples=10, sample_length=4096)

# %% [markdown]
# # **Applying permutation entropy and complexity**

# %%
# !pip install entropy
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for entropy: filename=entropy-0.1.5-py3-none-any.whl size=7177 sha256=243e36773a578cb5c695c77ae7987b81ca7400ab1bdf0123495dd5e8d9eed2b3
#   Stored in directory: /root/.cache/pip/wheels/81/ab/6d/d247a2eb9e7b8968acceab1d0531f2930ccf6688b61c0de460
# ...
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=a250233750f7662dd846c994af0b84f406d132cd42050ccf34e9ac7700c01c2b
#   Stored in directory: /root/.cache/pip/wheels/1a/b0/8c/4b75c4116c31f83c8f9f047231251e13cc74481cca4a78a9ce
# Successfully built entropy docopt
# ...

# %%
import numpy as np
import entropy as ent
import matplotlib.pyplot as plt

# %%
''' This module has essential functions supporting
fast and effective computation of permutation entropy and
its different variations.'''
import numpy as np


def s_entropy(freq_list):
    ''' This function computes the shannon entropy of a given frequency distribution.
    USAGE: shannon_entropy(freq_list)
    ARGS: freq_list = Numeric vector representing the frequency distribution
    OUTPUT: A numeric value representing shannon's entropy'''
    freq_list = [element for element in freq_list if element != 0]
    sh_entropy = 0.0
    for freq in freq_list:
        sh_entropy += freq * np.log(freq)
    sh_entropy = -sh_entropy
    return(sh_entropy)

def ordinal_patterns(ts, embdim, embdelay):
    ''' This function computes the ordinal patterns of a time series for a given embedding dimension and embedding delay.
    USAGE: ordinal_patterns(ts, embdim, embdelay)
    ARGS: ts = Numeric vector representing the time series, embdim = embedding dimension (3<=embdim<=7 prefered range), embdelay =  embdding delay
    OUPTUT: A numeric vector representing frequencies of ordinal patterns'''
    m, t = embdim, embdelay
    x = ts if isinstance(ts, np.ndarray) else np.array(ts)

    tmp = np.zeros((x.shape[0], m))
    for i in range(m):
        tmp[:, i] = np.roll(x, i*t)
    partition = tmp[(t*(m-1)):, :]
    permutation = np.argsort(partition)
    idx = _hash(permutation)

    counts = np.zeros(np.math.factorial(m))
    for i in range(counts.shape[0]):
        counts[i] = (idx == i).sum()
    return list(counts[counts != 0].astype(int))

def _hash(x):
    m, n = x.shape
    if n == 1:
        return np.zeros(m)
    return np.sum(np.apply_along_axis(lambda y: y < x[:, 0], 0, x), axis=1) * np.math.factorial(n-1) + _hash(x[:, 1:])


def p_entropy(op):
    ordinal_pat = op
    max_entropy = np.log(len(ordinal_pat))
    p = np.divide(np.array(ordinal_pat), float(sum(ordinal_pat)))
    return(s_entropy(p)/max_entropy)

def complexity(op):
    ''' This function computes the complexity of a time series defined as: Comp_JS = Q_o * JSdivergence * pe
    Q_o = Normalizing constant
    JSdivergence = Jensen-Shannon divergence
    pe = permutation entopry
    ARGS: ordinal pattern'''
    pe = p_entropy(op)
    constant1 = (0.5+((1 - 0.5)/len(op)))* np.log(0.5+((1 - 0.5)/len(op)))
    constant2 = ((1 - 0.5)/len(op))*np.log((1 - 0.5)/len(op))*(len(op) - 1)
    constant3 = 0.5*np.log(len(op))
    Q_o = -1/(constant1+constant2+constant3)

    temp_op_prob = np.divide(op, sum(op))
    temp_op_prob2 = (0.5*temp_op_prob)+(0.5*(1/len(op)))
    JSdivergence = (s_entropy(temp_op_prob2) - 0.5 * s_entropy(temp_op_prob) - 0.5 * np.log(len(op)))
    Comp_JS = Q_o * JSdivergence * pe
    return(Comp_JS)

def weighted_ordinal_patterns(ts, embdim, embdelay):
    m, t = embdim, embdelay
    x = ts if isinstance(ts, np.ndarray) else np.array(ts)

    tmp = np.zeros((x.shape[0], m))
    for i in range(m):
        tmp[:, i] = np.roll(x, i*t)
    partition = tmp[(t*(m-1)):, :]
    xm = np.mean(partition, axis=1)
    weight = np.mean((partition - xm[:, None])**2, axis=1)
    permutation = np.argsort(partition)
    idx = _hash(permutation)
    counts = np.zeros(np.math.factorial(m))
    for i in range(counts.shape[0]):
        counts[i] = sum(weight[i == idx])

    return list(counts[counts != 0])

# %%
import numpy as np
import pandas as pd

def calculate_pe_and_complexity_for_sampled_segments(sampled_segments, embdim=4, embdelay=1):

    results = []

    for segment in sampled_segments:

        segment_results = {}


        for column in segment.columns:
            if column not in ['label', 'subject']:
                time_series = segment[column].values

                if not isinstance(time_series, (np.ndarray, list)):
                    time_series = np.array([time_series])

                if len(time_series) < embdim * embdelay:

                    print(f"Skipping {column} in segment due to insufficient data points.")
                    continue

                try:

                    op = ordinal_patterns(time_series, embdim, embdelay)


                    pe_value = p_entropy(op)


                    comp_value = complexity(op)


                    segment_results[f"{column}_PE"] = pe_value
                    segment_results[f"{column}_Complexity"] = comp_value
                except Exception as e:
                    print(f"Error processing {column} in segment: {e}")
                    continue


        if segment_results:
            results.append(segment_results)


    results_df = pd.DataFrame(results)
    return results_df

# %%
results_dfS1_1 = calculate_pe_and_complexity_for_sampled_segments(sampled_segments=sampled_segments_dfS1_1)
results_dfS1_1['state']= 1
results_dfS1_2 = calculate_pe_and_complexity_for_sampled_segments(sampled_segments=sampled_segments_dfS1_2)
results_dfS1_2['state']= 2
results_dfS1_3 = calculate_pe_and_complexity_for_sampled_segments(sampled_segments=sampled_segments_dfS1_3)
results_dfS1_3['state']= 3
results_dfS1_4 = calculate_pe_and_complexity_for_sampled_segments(sampled_segments=sampled_segments_dfS1_4)
results_dfS1_4['state']= 4
results_dfS2_1 = calculate_pe_and_complexity_for_sampled_segments(sampled_segments=sampled_segments_dfS2_1)
results_dfS2_1['state']= 1
results_dfS2_2 = calculate_pe_and_complexity_for_sampled_segments(sampled_segments=sampled_segments_dfS2_2)
results_dfS2_2['state']= 2
results_dfS2_3 = calculate_pe_and_complexity_for_sampled_segments(sampled_segments=sampled_segments_dfS2_3)
results_dfS2_3['state']= 3
results_dfS2_4 = calculate_pe_and_complexity_for_sampled_segments(sampled_segments=sampled_segments_dfS2_4)
results_dfS2_4['state']= 4
results_dfS3_1 = calculate_pe_and_complexity_for_sampled_segments(sampled_segments=sampled_segments_dfS3_1)
results_dfS3_1['state']= 1
results_dfS3_2 = calculate_pe_and_complexity_for_sampled_segments(sampled_segments=sampled_segments_dfS3_2)
results_dfS3_2['state']= 2
results_dfS3_3 = calculate_pe_and_complexity_for_sampled_segments(sampled_segments=sampled_segments_dfS3_3)
results_dfS3_3['state']= 3
results_dfS3_4 = calculate_pe_and_complexity_for_sampled_segments(sampled_segments=sampled_segments_dfS3_4)
results_dfS3_4['state']= 4
results_dfS4_1 = calculate_pe_and_complexity_for_sampled_segments(sampled_segments=sampled_segments_dfS4_1)
results_dfS4_1['state']= 1
results_dfS4_2 = calculate_pe_and_complexity_for_sampled_segments(sampled_segments=sampled_segments_dfS4_2)
results_dfS4_2['state']= 2
results_dfS4_3 = calculate_pe_and_complexity_for_sampled_segments(sampled_segments=sampled_segments_dfS4_3)
results_dfS4_3['state']= 3
results_dfS4_4 = calculate_pe_and_complexity_for_sampled_segments(sampled_segments=sampled_segments_dfS4_4)
results_dfS4_4['state']= 4
results_dfS5_1 = calculate_pe_and_complexity_for_sampled_segments(sampled_segments=sampled_segments_dfS5_1)
results_dfS5_1['state']= 1
results_dfS5_2 = calculate_pe_and_complexity_for_sampled_segments(sampled_segments=sampled_segments_dfS5_2)
results_dfS5_2['state']= 2
results_dfS5_3 = calculate_pe_and_complexity_for_sampled_segments(sampled_segments=sampled_segments_dfS5_3)
results_dfS5_3['state']= 3
results_dfS5_4 = calculate_pe_and_complexity_for_sampled_segments(sampled_segments=sampled_segments_dfS5_4)
results_dfS5_4['state']= 4
# Out:
# <ipython-input-24-075a6a2cbc8c>:43: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   return np.sum(np.apply_along_axis(lambda y: y < x[:, 0], 0, x), axis=1) * np.math.factorial(n-1) + _hash(x[:, 1:])
# <ipython-input-24-075a6a2cbc8c>:34: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   counts = np.zeros(np.math.factorial(m))
# <ipython-input-24-075a6a2cbc8c>:43: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   return np.sum(np.apply_along_axis(lambda y: y < x[:, 0], 0, x), axis=1) * np.math.factorial(n-1) + _hash(x[:, 1:])
# ...

# %%
results_dfS1_1
# Out:
#    acc_x_PE  acc_x_Complexity  acc_y_PE  acc_y_Complexity  acc_z_PE  \
# 0  0.968643          0.037514  0.969641          0.037025  0.960654
# 1  0.973459          0.032454  0.974907          0.031179  0.966061
# 2  0.971025          0.035050  0.969902          0.036867  0.960182
# 3  0.970473          0.036377  0.972851          0.032742  0.965287
# 4  0.964883          0.041562  0.968254          0.038031  0.968047
# 5  0.967496          0.039382  0.972207          0.034425  0.958976
# 6  0.969881          0.035836  0.976481          0.029191  0.959189
# 7  0.965841          0.040186  0.977290          0.028115  0.966035
# 8  0.965430          0.041161  0.970051          0.036499  0.957022
# 9  0.965058          0.041759  0.967020          0.039418  0.959191
#
#    acc_z_Complexity    ECG_PE  ECG_Complexity    EMG_PE  EMG_Complexity  \
# 0          0.046608  0.683914        0.235475  0.994231        0.007661
# 1          0.040926  0.667710        0.243030  0.995196        0.006179
# ...

# %%
combinedResult_dfS1 = pd.concat([results_dfS1_1, results_dfS1_2, results_dfS1_3, results_dfS1_4], axis=0, ignore_index=True)
combinedResult_dfS2 = pd.concat([results_dfS2_1, results_dfS2_2, results_dfS2_3, results_dfS2_4], axis=0, ignore_index=True)
combinedResult_dfS3 = pd.concat([results_dfS3_1, results_dfS3_2, results_dfS3_3, results_dfS3_4], axis=0, ignore_index=True)
combinedResult_dfS4 = pd.concat([results_dfS4_1, results_dfS4_2, results_dfS4_3, results_dfS4_4], axis=0, ignore_index=True)
combinedResult_dfS5 = pd.concat([results_dfS5_1, results_dfS5_2, results_dfS5_3, results_dfS5_4], axis=0, ignore_index=True)

# %%
combinedResult_dfS1
# Out:
#     acc_x_PE  acc_x_Complexity  acc_y_PE  acc_y_Complexity  acc_z_PE  \
# 0   0.968643          0.037514  0.969641          0.037025  0.960654
# 1   0.973459          0.032454  0.974907          0.031179  0.966061
# 2   0.971025          0.035050  0.969902          0.036867  0.960182
# 3   0.970473          0.036377  0.972851          0.032742  0.965287
# 4   0.964883          0.041562  0.968254          0.038031  0.968047
# 5   0.967496          0.039382  0.972207          0.034425  0.958976
# 6   0.969881          0.035836  0.976481          0.029191  0.959189
# 7   0.965841          0.040186  0.977290          0.028115  0.966035
# 8   0.965430          0.041161  0.970051          0.036499  0.957022
# 9   0.965058          0.041759  0.967020          0.039418  0.959191
# 10  0.916383          0.088885  0.956990          0.049658  0.902623
# 11  0.948280          0.059023  0.970857          0.034827  0.946688
# 12  0.925983          0.079106  0.967293          0.038438  0.939291
# ...

# %% [markdown]
# # **Visualising the results**

# %% [markdown]
# **Scatter Plot of Complexity vs. Permutation Entropy**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def plot_pe_vs_complexity_by_state(df):

    attributes = ['acc_x', 'acc_y', 'acc_z', 'ECG', 'EMG', 'EDA', 'Temp', 'Resp']


    for attr in attributes:
        plt.figure(figsize=(8, 6))
        sns.scatterplot(
            data=df,
            x=f"{attr}_PE",
            y=f"{attr}_Complexity",
            hue="state",
            palette="viridis",

            s=100,
        )
        plt.title(f"{attr}: PE vs Complexity")
        plt.xlabel("Permutation Entropy (PE)")
        plt.ylabel("Complexity")
        plt.legend(title="State")
        plt.grid(True)
        plt.show()

# %%
plot_pe_vs_complexity_by_state(df=combinedResult_dfS1)
plot_pe_vs_complexity_by_state(df=combinedResult_dfS2)
plot_pe_vs_complexity_by_state(df=combinedResult_dfS3)
plot_pe_vs_complexity_by_state(df=combinedResult_dfS4)
plot_pe_vs_complexity_by_state(df=combinedResult_dfS5)
